# %% [markdown]
# # Сравнение предложений
# Каждая строка в файле соответствует одному предложению. Считайте их, приведите каждую к нижнему регистру с помощью строковой функции lower().

# %%
import re
with open ('1.txt') as file:
    s = file.read().lower()

# %% [markdown]
# Произведите токенизацию, то есть разбиение текстов на слова. Для этого можно воспользоваться регулярным выражением, которое считает разделителем любой символ, не являющийся буквой: re.split('[^a-z]', t). Не забудьте удалить пустые слова после разделения.

# %%
result = re.split('[^a-z]', s)
while '' in result:
    result.remove('')

# %% [markdown]
# Составьте список всех слов, встречающихся в предложениях. Сопоставьте каждому слову индекс от нуля до (d - 1), где d — число различных слов в предложениях. Для этого удобно воспользоваться структурой dict.

# %%
l1 = set(result)
l2 = [i for i in range (len(l1))]
d = dict(zip(l1,l2))
dd = dict(zip(l1,l2))
dd
# Out:
# {'they': 0,
#  'rather': 1,
#  'are': 2,
#  'count': 3,
#  'every': 4,
#  'starting': 5,
#  'as': 6,
#  'mountain': 7,
#  'october': 8,
#  'unix': 9,
#  'other': 10,
#  'clear': 11,
#  'version': 12,
#  'information': 13,
#  'disk': 14,
#  'cat': 15,
#  'ears': 16,
#  'both': 17,
#  'available': 18,
#  'july': 19,
#  'chromosomes': 20,
#  'simply': 21,
#  'non': 22,
#  'x': 23,
#  'during': 24,
#  'also': 25,
#  'however': 26,
#  'create': 27,
#  'cats': 28,
#  'apple': 29,
#  'standard': 30,
#  'time': 31,
#  'binary': 32,
#  'part': 33,
#  'and': 34,
#  'from': 35,
#  'redirection': 36,
#  'without': 37,
#  'bytes': 38,
#  'vermin': 39,
#  'unnecessary': 40,
#  'lion': 41,
#  'genes': 42,
#  'patch': 43,
#  'often': 44,
#  'commands': 45,
#  'command': 46,
#  'those': 47,
#  'where': 48,
#  'on': 49,
#  'predators': 50,
#  'offered': 51,
#  'useful': 52,
#  'high': 53,
#  'stdin': 54,
#  'selection': 55,
#  'three': 56,
#  'when': 57,
#  'predecessor': 58,
#  'concatenate': 59,
#  'recent': 60,
#  'mid': 61,
#  'be': 62,
#  'a': 63,
#  'over': 64,
#  'delete': 65,
#  'human': 66,
#  'symbol': 67,
#  'receives': 68,
#  'have': 69,
#  'osx': 70,
#  'sequence': 71,
#  'tamed': 72,
#  'in': 73,
#  'factory': 74,
#  'is': 75,
#  'terms': 76,
#  'lines': 77,
#  'members': 78,
#  'safari': 79,
#  'not': 80,
#  'second': 81,
#  'too': 82,
#  'size': 83,
#  'than': 84,
#  'an': 85,
#  'so': 86,
#  'typically': 87,
#  'incremental': 88,
#  'stdout': 89,
#  'leopard': 90,
#  'diploid': 91,
#  'online': 92,
#  'left': 93,
#  'use': 94,
#  'intel': 95,
#  'download': 96,
#  'or': 97,
#  'comparison': 98,
#  'any': 99,
#  'it': 100,
#  'enhancements': 101,
#  'versions': 102,
#  'most': 103,
#  'one': 104,
#  'used': 105,
#  'won': 106,
#  's': 107,
#  'default': 108,
#  'marks': 109,
#  'permanently': 110,
#  'ancestor': 111,
#  'catenates': 112,
#  'concern': 113,
#  'learned': 114,
#  'more': 115,
#  'felis': 116,
#  'editions': 117,
#  'separate': 118,
#  'features': 119,
#  'faint': 120,
#  'common': 121,
#  'organisms': 122,
#  'will': 123,
#  'was': 124,
#  'read': 125,
#  'contains': 126,
#  'named': 127,
#  'domestic': 128,
#  'domesticated': 129,
#  'purchase': 130,
#  'made': 131,
#  'instead': 132,
#  'computers': 133,
#  'error': 134,
#  'can': 135,
#  'process': 136,
#  'interactive': 137,
#  'according': 138,
#  'store': 139,
#  'wild': 140,
#  'wrong': 141,
#  'installation': 142,
#  'world': 143,
#  'may': 144,
#  'artificial': 145,
#  'received': 146,
#  'arguments': 147,
#  'tiger': 148,
#  'small': 149,
#  'right': 150,
#  'which': 151,
#  'moved': 152,
#  't': 153,
#  'update': 154,
#  'drive': 155,
#  'entirely': 156,
#  'dogs': 157,
#  'place': 158,
#  'undergone': 159,
#  'for': 160,
#  'were': 161,
#  'released': 162,
#  'new': 163,
#  'files': 164,
#  'switch': 165,
#  'fifth': 166,
#  'such': 167,
#  'based': 168,
#  'now': 169,
#  'off': 170,
#  'piped': 171,
#  'file': 172,
#  'installs': 173,
#  'deliberately': 174,
#  'processors': 175,
#  'domestication': 176,
#  'needing': 177,
#  'allows': 178,
#  'mavericks': 179,
#  'longer': 180,
#  'basic': 181,
#  'later': 182,
#  'using': 183,
#  'possess': 184,
#  'type': 185,
#  'its': 186,
#  'through': 187,
#  'since': 188,
#  'to': 189,
#  'two': 190,
#  'output': 191,
#  'that': 192,
#  'yosemite': 193,
#  'genus': 194,
#  'successor': 195,
#  'app': 196,
#  'single': 197,
#  'kg': 198,
#  'major': 199,
#  'weighing': 200,
#  'adjacent': 201,
#  'has': 202,
#  'hear': 203,
#  'the': 204,
#  'mice': 205,
#  'just': 206,
#  'running': 207,
#  'frequency': 208,
#  'keyboards': 209,
#  'content': 210,
#  'safer': 211,
#  'firmware': 212,
#  'no': 213,
#  'os': 214,
#  'symbols': 215,
#  'allow': 216,
#  'external': 217,
#  'releasing': 218,
#  'closest': 219,
#  'people': 220,
#  'installed': 221,
#  'mac': 222,
#  'release': 223,
#  'flow': 224,
#  'redirected': 225,
#  'connected': 226,
#  'between': 227,
#  'pipes': 228,
#  'animals': 229,
#  'by': 230,
#  'similar': 231,
#  'legibility': 232,
#  'community': 233,
#  'lb': 234,
#  'you': 235,
#  'developed': 236,
#  'upgrade': 237,
#  'with': 238,
#  'sounds': 239,
#  'roughly': 240,
#  'year': 241,
#  'run': 242,
#  'linux': 243,
#  'of': 244,
#  'started': 245,
#  'releases': 246,
#  'changes': 247,
#  'their': 248,
#  'if': 249,
#  'displays': 250,
#  'streams': 251,
#  'need': 252,
#  'some': 253}

# %% [markdown]
# Создайте матрицу размера n * d, где n — число предложений. Заполните ее: элемент с индексом (i, j) в этой матрице должен быть равен количеству вхождений j-го слова в i-е предложение. У вас должна получиться матрица размера 22 * 254.

# %%
import numpy as np
with open ('1.txt') as file:
    a = file.read().lower().splitlines() #создаем список где предложение-=элемент
x = []
for ii in a:
    ii = ii.split()
    for i in d.keys():
        if i in ii:
            d[i] = ii.count(i)
        else:
            d[i] = 0
    z = list(d.values())
    x += [z]
m = np.array (x)
np.sum(m) #дб 496
# Out:
# 423

# %% [markdown]
# Найдите косинусное расстояние от предложения в самой первой строке (In comparison to dogs, cats have not undergone...) до всех остальных с помощью функции scipy.spatial.distance.cosine. Какие номера у двух предложений, ближайших к нему по этому расстоянию (строки нумеруются с нуля)? Эти два числа и будут ответами на задание. Само предложение (In comparison to dogs, cats have not undergone... ) имеет индекс 0.

# %%
from scipy.spatial import distance
a = m[0,:]
#a = a.reshape (1,254)
p = 2
x = []
for i in range (1, len(m)):
    b = m[i,:]
   # b = b.reshape(1,254)
    c = distance.cosine (a, b)
    x+= [c]
    print ("Косинусное расстояние между 1 векторм и вектором", p, "равно", c, '\n')
    p+=1
print (sorted (x))
# Out:
# Косинусное расстояние между 1 векторм и вектором 2 равно 0.9444444444444444
#
# Косинусное расстояние между 1 векторм и вектором 3 равно 0.8469068910760513
#
# Косинусное расстояние между 1 векторм и вектором 4 равно 0.882148869802242
#
# Косинусное расстояние между 1 векторм и вектором 5 равно 0.8063508326896291
#
# Косинусное расстояние между 1 векторм и вектором 6 равно 0.9337733821467478
#
# Косинусное расстояние между 1 векторм и вектором 7 равно 0.699035367285577
#
# Косинусное расстояние между 1 векторм и вектором 8 равно 0.9087129070824723
#
# Косинусное расстояние между 1 векторм и вектором 9 равно 0.8709005551264194
#
# Косинусное расстояние между 1 векторм и вектором 10 равно 0.9444444444444444
#
# Косинусное расстояние между 1 векторм и вектором 11 равно 0.8153627635310009
#
# Косинусное расстояние между 1 векторм и вектором 12 равно 0.8639172365120457
#
# Косинусное расстояние между 1 векторм и вектором 13 равно 0.8194212203713462
#
# Косинусное расстояние между 1 векторм и вектором 14 равно 0.850928801500014
#
# Косинусное расстояние между 1 векторм и вектором 15 равно 0.850928801500014
#
# Косинусное расстояние между 1 векторм и вектором 16 равно 0.9384542545103336
#
# Косинусное расстояние между 1 векторм и вектором 17 равно 0.7958758547680685
#
# Косинусное расстояние между 1 векторм и вектором 18 равно 0.9504926228511663
#
# Косинусное расстояние между 1 векторм и вектором 19 равно 0.9354502775632098
#
# Косинусное расстояние между 1 векторм и вектором 20 равно 0.8740118423302576
#
# Косинусное расстояние между 1 векторм и вектором 21 равно 0.8153627635310009
#
# Косинусное расстояние между 1 векторм и вектором 22 равно 0.7834936490538903
#
# [0.699035367285577, 0.7834936490538903, 0.7958758547680685, 0.8063508326896291, 0.8153627635310009, 0.8153627635310009, 0.8194212203713462, 0.8469068910760513, 0.850928801500014, 0.850928801500014, 0.8639172365120457, 0.8709005551264194, 0.8740118423302576, 0.882148869802242, 0.9087129070824723, 0.9337733821467478, 0.9354502775632098, 0.9384542545103336, 0.9444444444444444, 0.9444444444444444, 0.9504926228511663]

# %%
from scipy.spatial import distance
a = m[0,:]
a = a.reshape (1,254)
b = m[1,:]
b = b.reshape(1,254)
c = distance.cosine (a, b)
c
# Out:
# 0.9444444444444444
